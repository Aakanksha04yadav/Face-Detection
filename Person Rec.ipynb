# %%
#import required libraries
#import OpenCV library
import cv2
#import matplotlib library
import matplotlib.pyplot as plt
#importing time library for speed comparisons of both classifiers
import time
# %matplotlib inline
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
import os

from google.colab.patches import cv2_imshow
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
from google.colab.patches import cv2_imshow
img =cv2.imread("/gdrive/My Drive/Colab Notebooks/Selff.jpg",1)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=470x470>

# %%
def convertToRGB(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
#load test iamge
test1 = cv2.imread('/gdrive/My Drive/Colab Notebooks/Selff.jpg')

#convert the test image to gray image as opencv face detector expects gray images
gray_img = cv2.cvtColor(test1, cv2.COLOR_BGR2GRAY)

# %%
#if you have matplotlib installed then
plt.imshow(gray_img, cmap='gray')

# or display the gray image using OpenCV
# cv2.imshow('Test Imag', gray_img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
#load cascade classifier training file for haarcascade
haar_face_cascade = cv2.CascadeClassifier('/gdrive/My Drive/Colab Notebooks/haarcascade_frontalface_alt.xml')

# %%
xml_path = os.path.abspath('/gdrive/My Drive/Colab Notebooks/haarcascade_frontalface_default.xml')
haar_face_cascade = cv2.CascadeClassifier(xml_path)

# %%
#let's detect multiscale (some images may be closer to camera than others) images
faces = haar_face_cascade.detectMultiScale(gray_img, scaleFactor=1.1, minNeighbors=5);

#print the number of faces found
print('Faces found: ', len(faces))
# Out:
# Faces found:  1

# %%
#go over list of faces and draw them as rectangles on original colored img
for (x, y, w, h) in faces:
    cv2.rectangle(test1, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
#conver image to RGB and show image
plt.imshow(convertToRGB(test1))
